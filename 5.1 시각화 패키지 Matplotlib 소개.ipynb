# %% [markdown]
# - line plot
# - scatter plot
# - contour plot
# - surface plot
# - bar chart
# - histogram
# - box plot

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %% [markdown]
# ### 라인 플롯
# - 데이터가 시간, 순서 등에 따라 어떻게 변화하는지 보여주기 위해 사용

# %%
plt.title('Plot')
plt.plot([1,4,9,16]) # x tick 자동으로 0,1,2,3이 된다
plt.show()

# %%
plt.title('x ticks')
plt.plot([10,20,30,40],[1,4,9,16]) # x tick 위치를 별도로 명시
plt.show()

# %% [markdown]
# ### 한글폰트 사용

# %%
sudo apt install -y fonts-nanum*
sudo fc-cache -fv
rm ~/.cache/matplotlib -rf
# Out:
#   File "C:\Users\82109\AppData\Local\Temp/ipykernel_18416/3390171840.py", line 1
#     sudo apt install -y fonts-nanum*
#          ^
# SyntaxError: invalid syntax

# %%
import matplotlib.font_manager

matplotlib.font_manager._rebuild()
sorted([f.name for f in matplotlib.font_manager.fontManager.ttflist if f.name.startswith("Nanum")]
# Out:
#   File "C:\Users\82109\AppData\Local\Temp/ipykernel_18416/3508290934.py", line 4
#     sorted([f.name for f in matplotlib.font_manager.fontManager.ttflist if f.name.startswith("Nanum")]
#                                                                                                       ^
# SyntaxError: unexpected EOF while parsing

# %%
# 폰트 설정
mpl.rc('font', family='NanumGothic')
# 유니코드에서  음수 부호설정
mpl.rc('axes', unicode_minus=False)

# %%
plt.title('한글 제목')
plt.plot([10,20,30,40],[1,4,9,16])
plt.xlabel('엑스축 라벨')
plt.ylabel('와이축 라벨')
plt.show()

# %%
font1 = {'family': 'NanumMyeongjo', 'size': 24, 
         'color':  'black'}
font2 = {'family': 'NanumBarunpen', 'size': 18, 'weight': 'bold',
         'color':  'darkred'}
font3 = {'family': 'NanumBarunGothic', 'size': 12, 'weight': 'light',
         'color':  'blue'}

plt.plot([10, 20, 30, 40], [1, 4, 9, 16])
plt.title('한글 제목', fontdict=font1)
plt.xlabel('엑스 축', fontdict=font2)
plt.ylabel('와이 축', fontdict=font3)
plt.show()
